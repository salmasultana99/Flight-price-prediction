# %% [markdown]
# # Flight Price Prediction

# %% [markdown]
# Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travellers saying that flight ticket prices are so unpredictable.
#
# Here we will be provided with prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.

# %% [markdown]
# # Importing Data

# %%
import pandas as pd
Flight_Train=pd.read_excel("Data_Train.xlsx") #reading Flight_Train.xlsx file
Flight_Train.head() #Looking into top 5 rows
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
Flight_Train.shape #Checking the shape of our data
# Out:
# (10683, 11)

# %%
Flight_Train.dtypes #Checking the datatype of each attribute
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# As per problem statement Target variable i.e. Price is int64 i.e. continuous. so we'll use Reqression to learn our model.

# %% [markdown]
# # Handling Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize = (16,5))
sns.heatmap(Flight_Train.isnull()) #Looking for null values if any, in heatmap
# Out:
# <AxesSubplot:>

# %%
print(Flight_Train.isnull().sum(axis = 0))
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
#Replacing null values with mode becuase the type of objects are object
Flight_Train['Route'].fillna(Flight_Train['Route'].mode()[0], inplace=True)
Flight_Train['Total_Stops'].fillna(Flight_Train['Total_Stops'].mode()[0], inplace=True)

# %%
plt.figure(figsize = (16,5))
sns.heatmap(Flight_Train.isnull()) #Looking for null values if any, in heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we are performing some feature engineering step for EDA just to get better clearity of data.

# %% [markdown]
# ## Univariate Analysis

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
print(Flight_Train['Source'].value_counts())
plt.figure(figsize = (10,5))
sns.countplot(x="Source", data=Flight_Train)
plt.title("Source of Flight", fontsize = 20)
plt.show()
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %% [markdown]
# We can clearly see that Maximum number of Filght Source was Delhi or we can say 4537 Flights source was Delhi.

# %%
print(Flight_Train['Destination'].value_counts())
plt.figure(figsize = (10,5))
sns.countplot(x="Destination", data=Flight_Train)
plt.title("Destination of Flight", fontsize = 20)
plt.show()
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %% [markdown]
# 4537 Flight Destination was Cochin i.e. Maximum

# %%
print(Flight_Train['Total_Stops'].value_counts())
plt.figure(figsize = (10,5))
sns.countplot(x="Total_Stops", data=Flight_Train)
plt.title("Total_Stops of Flight", fontsize = 20)
plt.show()
# Out:
# 1 stop      5626
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# Most of the flights were having 1stop i.e. 5626 or 0stops i.e. 3491

# %%
print(Flight_Train['Additional_Info'].value_counts())
plt.figure(figsize = (20,5)) #Plotting with size of 10 * 5
ax=sns.countplot(x="Additional_Info", data=Flight_Train) #Plotting Countplot for Additional_Info
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title("Additional_Info of Flight", fontsize = 20) #Setting up the title
plt.show() #plotting the graph
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# Red-eye flight                     1
# 1 Short layover                    1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# Generally there was no Infomation in flight.

# %%
print(Flight_Train['Airline'].value_counts())
plt.figure(figsize = (20,5)) #Plotting with size of 10 * 5
ax=sns.countplot(x="Airline", data=Flight_Train) #Plotting Countplot for Airline
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title("Airline of Flight", fontsize = 20) #Setting up the title
plt.show() #plotting the graph
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %% [markdown]
# Mostly Jet Airways Airlines Filghts fly in sky.

# %% [markdown]
# ## Bi-variate Analysis

# %%
Flight_Train['Date_of_Journey'] = pd.to_datetime(Flight_Train['Date_of_Journey'], errors='coerce')
plt.figure(figsize = (20,5))
ax = sns.lineplot(x="Date_of_Journey",y="Price",  data=Flight_Train)
plt.title("Date_of_Journey vs Price", fontsize = 20)
plt.show()

# %% [markdown]
# In January starting Flight prices were high(20,000) than suddenly in dropped to 7500.
# After that Flight prices slightly increaing from jcn to march 8000 to 12500.
# In March and April flight prices are slightly decresing and incering multiple times.
# From May to June prices are going high.
# June and Juy prices are going up and down.
# July till September price increasing suddenlt price down and than again it's going high till mid of november.

# %%
plt.figure(figsize = (20,10))
ax=sns.boxplot(Flight_Train['Additional_Info'], Flight_Train['Price'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title('Price vs Additional_Info')
plt.show()

# %% [markdown]
# Here few things we can notice -
# 1. The Flight price is too low when No check-in baggage were allowed.
# 2. When customer choose Business Class that time Price goes too high.
# 2. When No meal provided in Flight that time flight prices are always lesser than 20,000.

# %%
plt.figure(figsize = (20,10))
sns.boxplot(Flight_Train['Source'], Flight_Train['Price'])
plt.title('Price vs Source')
plt.show()

# %% [markdown]
# From Chennai and Mumbai the flights are cheaper as compared with other Sources

# %%
plt.figure(figsize = (20,10))
sns.boxplot(Flight_Train['Destination'], Flight_Train['Price'])
plt.title('Price vs Destination')
plt.show()

# %% [markdown]
# Kolkata, Delhi and Hyderabad flights are cheaper than other Destination price

# %%
plt.figure(figsize = (20,10))
sns.boxplot(Flight_Train['Total_Stops'], Flight_Train['Price'])
plt.title('Price vs Total_Stops')
plt.show()

# %% [markdown]
# Non-Stops flights are cheaper

# %%
plt.figure(figsize = (20,10))
ax=sns.boxplot(Flight_Train['Airline'], Flight_Train['Price'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title('Price vs Airline')
plt.show()

# %% [markdown]
# Jet Airways flights are always expencive and Spivejet flights are cheaper.

# %% [markdown]
# We'll do furter EDA after Feature Engineering and label Encoding

# %% [markdown]
# # Feature Engineering

# %%
#Checking the unique values will number count.
Flight_Train['Additional_Info'].value_counts()
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# Red-eye flight                     1
# 1 Short layover                    1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# We can clearly see that No Info is No info, it's just typo error. So we'll fix it.

# %%
#Replacing No Info to No info.
Flight_Train["Additional_Info"]=Flight_Train["Additional_Info"].replace("No Info","No info")

# %%
#Checking the number of Total Stops
Flight_Train['Total_Stops'].value_counts()
# Out:
# 1 stop      5626
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
#Replacing String to numeric for better prediction
Flight_Train.replace({"non-stop": 0, 
                      "1 stop": 1, 
                      "2 stops": 2, 
                      "3 stops": 3, 
                      "4 stops": 4
                     }, inplace = True)

# %%
#Checking value count of stops
Flight_Train['Total_Stops'].value_counts()
# Out:
# 1    5626
# 0    3491
# 2    1520
# 3      45
# 4       1
# Name: Total_Stops, dtype: int64

# %%
#Checking first 5 rows of data
Flight_Train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m            0         No info   3897
# 1    05:50         13:15   7h 25m            2         No info   7662
# 2    09:25  04:25 10 Jun      19h            2         No info  13882
# 3    18:05         23:30   5h 25m            1         No info   6218
# 4    16:50         21:35   4h 45m            1         No info  13302

# %%
#Converting Duration from string to numbers
Flight_Train['hour'] = Flight_Train['Duration'].str.split("h").str[0]
Flight_Train['nothing'] = Flight_Train['Duration'].str.split(" ").str[1]
Flight_Train['minute'] = Flight_Train['nothing'].str.split("m").str[0]
Flight_Train.drop('nothing',axis=1,inplace=True)

# %%
Flight_Train['hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %% [markdown]
# We got 5m because the duration was 5m, Now we'll change hour to 0 and minute to 5

# %%
for i in range(0,10682):
    if(Flight_Train['hour'][i] == '5m'):
        Flight_Train["hour"][i] = 0
        Flight_Train["minute"][i] = 5

# %%
import numpy as np
Flight_Train['hour'] = pd.to_numeric(Flight_Train['hour']) #Converting object to numeric
Flight_Train['minute'] = pd.to_numeric(Flight_Train['minute']) #Converting object to numeric
Flight_Train['minute']=Flight_Train['minute'].replace(np.NaN,0) #Replacing null values with 0
Flight_Train['minute'] = Flight_Train['minute'].astype('int64') #Converting float to int
Flight_Train['Duration'] = Flight_Train['hour']*60 + Flight_Train['minute'] #Converting hours and minutes into minutes
Flight_Train.drop('hour',axis=1,inplace=True) #Dropping hour becuase work is over
Flight_Train.drop('minute',axis=1,inplace=True) #Dropping minute becuase work is over
Flight_Train.head() #Checking first 5 rows of data
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time  Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar       170            0         No info   3897
# 1    05:50         13:15       445            2         No info   7662
# 2    09:25  04:25 10 Jun      1140            2         No info  13882
# 3    18:05         23:30       325            1         No info   6218
# 4    16:50         21:35       285            1         No info  13302

# %%
#Converting Departure time into minutes
Flight_Train['Dep_Time'] = pd.to_datetime(Flight_Train['Dep_Time'],format = '%H:%M').dt.hour*60 + pd.to_datetime(Flight_Train['Dep_Time'],format = '%H:%M').dt.minute

# %%
#Converting date into numeric form
import datetime as dt
Flight_Train['Date_of_Journey'] = pd.to_datetime(Flight_Train['Date_of_Journey'])
Flight_Train['Date_of_Journey'] = Flight_Train['Date_of_Journey'].map(dt.datetime.toordinal)
Flight_Train.head() #Checking top 5 rows of dataset
# Out:
#        Airline  Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo           737142  Banglore   New Delhi              BLR → DEL
# 1    Air India           737064   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways           737308     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo           737398   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo           737062  Banglore   New Delhi        BLR → NAG → DEL
#
#    Dep_Time  Arrival_Time  Duration  Total_Stops Additional_Info  Price
# 0      1340  01:10 22 Mar       170            0         No info   3897
# 1       350         13:15       445            2         No info   7662
# 2       565  04:25 10 Jun      1140            2         No info  13882
# 3      1085         23:30       325            1         No info   6218
# 4      1010         21:35       285            1         No info  13302

# %%
#We have Total_Stops columns, So we don't need Route column
#We have Dep_Time and Duration that is equailent to Arrival time, So we don't need it.
Flight_Train.drop('Route',axis=1,inplace=True)
Flight_Train.drop('Arrival_Time',axis=1,inplace=True)

# %%
Flight_Train.head()
# Out:
#        Airline  Date_of_Journey    Source Destination  Dep_Time  Duration  \
# 0       IndiGo           737142  Banglore   New Delhi      1340       170
# 1    Air India           737064   Kolkata    Banglore       350       445
# 2  Jet Airways           737308     Delhi      Cochin       565      1140
# 3       IndiGo           737398   Kolkata    Banglore      1085       325
# 4       IndiGo           737062  Banglore   New Delhi      1010       285
#
#    Total_Stops Additional_Info  Price
# 0            0         No info   3897
# 1            2         No info   7662
# 2            2         No info  13882
# 3            1         No info   6218
# 4            1         No info  13302

# %% [markdown]
# # Label Encoding

# %%
#Label encoding for the object columns
label_list=list(Flight_Train.select_dtypes(['object']).columns)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() #Initlize LabelEncoder to le 
for i in label_list:
    Flight_Train[i] = le.fit_transform(Flight_Train[i])

# %%
#Multivariate Analysis
fig=plt.figure(figsize=(20,10))
hc=Flight_Train.corr(method='pearson')
sns.heatmap(hc,annot=True,cmap="Blues",linewidths=.1, annot_kws={"size": 10})
plt.title("correlation matrix")
plt.show()

# %% [markdown]
# Price is highly corelated with Duration and Total_Stops

# %%
Flight_Train.describe()
# Out:
#             Airline  Date_of_Journey        Source   Destination  \
# count  10683.000000     10683.000000  10683.000000  10683.000000
# mean       3.965927    737208.509033      1.952261      1.436113
# std        2.352155        89.113653      1.177221      1.474782
# min        0.000000    737062.000000      0.000000      0.000000
# 25%        3.000000    737142.000000      2.000000      0.000000
# 50%        4.000000    737203.000000      2.000000      1.000000
# 75%        4.000000    737237.000000      3.000000      2.000000
# max       11.000000    737399.000000      4.000000      5.000000
#
#            Dep_Time      Duration   Total_Stops  Additional_Info         Price
# count  10683.000000  10683.000000  10683.000000     10683.000000  10683.000000
# mean     773.852382    643.093232      0.824207         6.582140   9087.064121
# std      344.964055    507.862001      0.675199         0.838073   4611.359167
# min       20.000000      5.000000      0.000000         0.000000   1759.000000
# 25%      480.000000    170.000000      0.000000         7.000000   5277.000000
# 50%      710.000000    520.000000      1.000000         7.000000   8372.000000
# 75%     1085.000000    930.000000      1.000000         7.000000  12373.000000
# max     1435.000000   2860.000000      4.000000         8.000000  79512.000000

# %% [markdown]
# There is difference between Mean and std of Price of Outliers must be present in it.

# %%
#Correlation with Price with respect to attributes
Flight_Train.corrwith(Flight_Train.Price).plot.bar(
        figsize = (20, 8), title = "Correlation with Price Graph", fontsize = 12,
        rot = 30, grid = True)
# Out:
# <AxesSubplot:title={'center':'Correlation with Price Graph'}>

# %% [markdown]
# As we saw earlier Duration and Total_Stops are heighly corealted with Price

# %% [markdown]
# # Removing Skewness and Outliers

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(Flight_Train))
print(np.where(z>3))
# Out:
# (array([  123,   226,   396,   402,   486,   510,   553,   597,   628,
#          657,   785,   785,   826,   919,   936,   946,   959,   966,
#          969,   975,  1043,  1067,  1113,  1196,  1218,  1246,  1341,
#         1346,  1424,  1442,  1466,  1478,  1496,  1551,  1629,  1654,
#         1657,  1665,  1712,  1785,  1791,  1804,  1918,  2055,  2079,
#         2099,  2108,  2172,  2172,  2405,  2481,  2495,  2495,  2553,
#         2556,  2556,  2618,  2623,  2633,  2635,  2641,  2654,  2693,
#         2718,  2718,  2814,  2822,  2883,  2924,  2924,  3032,  3032,
#         3111,  3111,  3157,  3220,  3257,  3317,  3400,  3457,  3496,
#         3535,  3535,  3568,  3584,  3700,  3700,  3788,  3790,  3815,
#         3815,  3945,  3966,  4012,  4047,  4118,  4118,  4463,  4463,
#         4521,  4521,  4655,  4655,  4676,  4760,  4829,  5013,  5013,
#         5050,  5136,  5372,  5372,  5439,  5446,  5516,  5628,  5662,
#         5701,  5701,  5710,  5711,  5719,  5738,  5745,  5782,  5838,
#         5856,  5933,  5947,  5953,  5986,  5996,  6024,  6059,  6085,
#         6314,  6321,  6336,  6407,  6444,  6476,  6576,  6576,  6588,
#         6599,  6605,  6884,  6884,  6991,  7001,  7031,  7189,  7232,
#         7249,  7306,  7329,  7351,  7356,  7377,  7537,  7553,  7554,
#         7586,  7611,  7612,  7617,  7713,  7724,  7724,  7752,  7756,
#         7876,  7876,  7902,  7906,  8020,  8080,  8127,  8153,  8153,
#         8204,  8360,  8409,  8412,  8451,  8470,  8536,  8598,  8601,
#         8601,  8621,  8698,  8729,  8729,  8856,  8897,  8940,  8957,
#         8957,  8990,  9019,  9019,  9029,  9182,  9182,  9193,  9239,
#         9247,  9396,  9454,  9479,  9484,  9484,  9551,  9569,  9632,
#         9657,  9673,  9703,  9715,  9848,  9974, 10020, 10052, 10113,
#        10149, 10160, 10182, 10189, 10326, 10353, 10364, 10364, 10383,
#        10439, 10456, 10511, 10511, 10639, 10639], dtype=int64), array([8, 5, 8, 6, 8, 8, 5, 8, 8, 8, 7, 8, 8, 6, 8, 8, 8, 5, 5, 8, 7, 5,
#        5, 8, 6, 8, 8, 5, 8, 5, 8, 8, 5, 5, 8, 8, 5, 6, 7, 8, 5, 5, 8, 8,
#        7, 8, 8, 5, 6, 7, 7, 7, 8, 5, 7, 8, 8, 6, 6, 8, 5, 5, 8, 5, 6, 6,
#        6, 7, 7, 8, 7, 8, 7, 8, 6, 6, 8, 6, 8, 5, 6, 7, 8, 6, 6, 7, 8, 7,
#        5, 5, 6, 6, 5, 8, 5, 5, 6, 5, 6, 7, 8, 5, 6, 8, 6, 8, 7, 8, 6, 8,
#        7, 8, 8, 6, 5, 7, 8, 5, 8, 8, 5, 8, 8, 8, 5, 6, 8, 5, 6, 5, 8, 6,
#        7, 5, 5, 8, 5, 7, 8, 6, 5, 7, 8, 8, 6, 8, 5, 6, 8, 6, 6, 5, 5, 6,
#        5, 5, 8, 8, 8, 8, 5, 8, 6, 5, 5, 8, 8, 7, 8, 6, 8, 5, 6, 8, 5, 8,
#        8, 5, 5, 6, 6, 5, 5, 5, 8, 8, 8, 8, 5, 6, 5, 5, 5, 6, 8, 7, 8, 7,
#        8, 8, 7, 8, 6, 6, 7, 8, 8, 5, 5, 6, 7, 5, 6, 5, 6, 8, 7, 5, 5, 8,
#        5, 8, 5, 8, 8, 7, 8, 8, 8, 5, 8, 7, 8, 8, 8, 5, 7, 8, 5, 6],
#       dtype=int64))

# %%
z=np.abs(zscore(Flight_Train))
threshold=3
new_Flight_Train=Flight_Train[(z<3).all(axis=1)]
print(Flight_Train.shape)
print(new_Flight_Train.shape)
# Out:
# (10683, 9)
# (10475, 9)

# %%
#checking for how much data we lost
loss_percent=(10683-10475)/10683*100
print(loss_percent)
# Out:
# 1.9470186277262942

# %% [markdown]
# We lost almost 2% of our data, which is not bad.

# %%
#Checking skewness of all columns
new_Flight_Train.skew()
# Out:
# Airline            0.730109
# Date_of_Journey    0.486566
# Source            -0.438959
# Destination        1.266475
# Dep_Time           0.113216
# Duration           0.779912
# Total_Stops        0.230633
# Additional_Info   -1.468582
# Price              0.415788
# dtype: float64

# %%
new_Flight_Train.head()
# Out:
#    Airline  Date_of_Journey  Source  Destination  Dep_Time  Duration  \
# 0        3           737142       0            5      1340       170
# 1        1           737064       3            0       350       445
# 2        4           737308       2            1       565      1140
# 3        3           737398       3            0      1085       325
# 4        3           737062       0            5      1010       285
#
#    Total_Stops  Additional_Info  Price
# 0            0                7   3897
# 1            2                7   7662
# 2            2                7  13882
# 3            1                7   6218
# 4            1                7  13302

# %%
#Removing skewness
from sklearn.preprocessing import PowerTransformer
PT=PowerTransformer()
for i in new_Flight_Train.columns:
    if abs(new_Flight_Train.loc[:,i].skew())>0.55:
        new_Flight_Train.loc[:,i]=PT.fit_transform(new_Flight_Train.loc[:,i].values.reshape(-1,1))

# %%
new_Flight_Train.skew()
# Out:
# Airline           -0.013402
# Date_of_Journey    0.486566
# Source            -0.438959
# Destination        0.041017
# Dep_Time           0.113216
# Duration          -0.046552
# Total_Stops        0.230633
# Additional_Info   -1.136146
# Price              0.415788
# dtype: float64

# %% [markdown]
# # Seperating Input and Output Variables

# %%
y = new_Flight_Train["Price"]
x = new_Flight_Train.drop(["Price"], axis=1)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler() #Initializting MinMaxScaler
new = scale.fit(x)  #fitting our data into MinMaxScaller
scale_x = new.transform(x) #Transforming the data
#Setting up the coulumns after Scaling
scaled_x = pd.DataFrame(scale_x, index=x.index, columns=x.columns)
x=scaled_x
x.head() #Priting top 5 rows of our data
# Out:
#     Airline  Date_of_Journey  Source  Destination  Dep_Time  Duration  \
# 0  0.419360         0.237389    0.00     1.000000  0.932862  0.482236
# 1  0.176956         0.005935    0.75     0.000000  0.233216  0.660378
# 2  0.515086         0.729970    0.50     0.440768  0.385159  0.856249
# 3  0.419360         0.997033    0.75     0.000000  0.752650  0.599840
# 4  0.419360         0.000000    0.00     1.000000  0.699647  0.575230
#
#    Total_Stops  Additional_Info
# 0          0.0         0.165293
# 1          1.0         0.165293
# 2          1.0         0.165293
# 3          0.5         0.165293
# 4          0.5         0.165293

# %% [markdown]
# # Finding Best Random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_Score=0
maxRS=0
for i in range(1,1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=i)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    predrf = LR.predict(x_test)
    score = r2_score(y_test, predrf)
    if score>maxR2_Score:
        maxR2_Score=score
        maxRS=i
print("Best accuracy is",maxR2_Score," on Random_state ",maxRS)
# Out:
# Best accuracy is 0.5433243452764488  on Random_state  360

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %%
#importing all the required libraries to find best Algorithm
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
model=[LinearRegression(),RandomForestRegressor(),DecisionTreeRegressor(),KNeighborsRegressor(),GradientBoostingRegressor(),Ridge(),SVR()]

# %%
for m in model:
    print("*******************************************************************************")
    print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
    print('accuracy score of ->', m)
    m.fit(x_train,y_train)
    pred = m.predict(x_test)
    print("R2 Score:                ", r2_score(y_test,pred))
    print("Mean Absolute Error:     ", mean_absolute_error(y_test,pred))
    print("Mean Squared error:      ", mean_squared_error(y_test,pred))
    print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test,pred)))
    score=cross_val_score(m,x,y,cv=8)
    print(score)
    print("cross validation score:  ",score.mean())
    print("Difference between R2 score and cross validatio score is - ",r2_score(y_test,pred)-abs(score.mean()))
    print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
    print("*******************************************************************************")
# Out:
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> LinearRegression()
# R2 Score:                 0.5433243452764488
# Mean Absolute Error:      2157.0645389788497
# Mean Squared error:       7470645.752834695
# Root Mean Squared Error:  2733.24820549373
# [0.5218934  0.51507901 0.54378328 0.5228583  0.49113157 0.51343271
#  0.48271281 0.5369189 ]
# cross validation score:   0.515976248246264
# Difference between R2 score and cross validatio score is -  0.027348097030184815
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> RandomForestRegressor()
# R2 Score:                 0.8865722701987909
# Mean Absolute Error:      766.8271386982409
# Mean Squared error:       1855536.5917328014
# Root Mean Squared Error:  1362.1808219663062
# [0.8884856  0.90378916 0.89496665 0.89180028 0.87588551 0.8860383
#  0.8830396  0.8757257 ]
# cross validation score:   0.887466349385547
# Difference between R2 score and cross validatio score is -  -0.0008940791867561027
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> DecisionTreeRegressor()
# R2 Score:                 0.8257852049461476
# Mean Absolute Error:      823.0868066603032
# Mean Squared error:       2849937.379600169
# Root Mean Squared Error:  1688.1757549497531
# [0.81757644 0.84601141 0.81191155 0.83426703 0.81225791 0.80194349
#  0.83481037 0.81236215]
# cross validation score:   0.821392543450127
# Difference between R2 score and cross validatio score is -  0.004392661496020578
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> KNeighborsRegressor()
# R2 Score:                 0.7575595425252143
# Mean Absolute Error:      1276.0743875278397
# Mean Squared error:       3966024.3659051866
# Root Mean Squared Error:  1991.4879778460092
# [0.77392131 0.77000133 0.79846912 0.77084926 0.76469301 0.74364036
#  0.74509903 0.75613914]
# cross validation score:   0.7653515699006106
# Difference between R2 score and cross validatio score is -  -0.007792027375396304
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> GradientBoostingRegressor()
# R2 Score:                 0.815870890670529
# Mean Absolute Error:      1235.025953087315
# Mean Squared error:       3012123.2309135143
# Root Mean Squared Error:  1735.5469543960814
# [0.81711833 0.82080217 0.8298909  0.83029614 0.81273099 0.80289755
#  0.81209085 0.81836611]
# cross validation score:   0.8180241300431357
# Difference between R2 score and cross validatio score is -  -0.0021532393726066967
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> Ridge()
# R2 Score:                 0.5432707905353087
# Mean Absolute Error:      2157.21681158434
# Mean Squared error:       7471521.84179478
# Root Mean Squared Error:  2733.4084659623745
# [0.52207565 0.51480954 0.54364364 0.52278706 0.49126627 0.51340793
#  0.48270987 0.53708249]
# cross validation score:   0.5159728068760019
# Difference between R2 score and cross validatio score is -  0.0272979836593068
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> SVR()
# R2 Score:                 0.1089793836924835
# Mean Absolute Error:      3164.5690789216505
# Mean Squared error:       14575989.138145354
# Root Mean Squared Error:  3817.8513771682306
# [0.14289441 0.1008356  0.12298676 0.12321475 0.12151827 0.14127857
#  0.13084478 0.13082065]
# cross validation score:   0.1267992226985708
# Difference between R2 score and cross validatio score is -  -0.0178198390060873
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************

# %% [markdown]
# Random Forest Regressor model have heighest accuracy i.e. 88.59% with 88.77% cross validation score which is good and the difference is too less.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = {"max_depth":range(21,25),
              "criterion":['mse'],
              "max_features": ['auto', 'sqrt'],
              "min_samples_leaf":range(1,5)}

clf = GridSearchCV(RandomForestRegressor(), parameters)
clf.fit(x_train,y_train) #fitting train and test data
clf.best_params_  #Best parameters
# Out:
# {'criterion': 'mse',
#  'max_depth': 22,
#  'max_features': 'auto',
#  'min_samples_leaf': 1}

# %%
clf_pred=clf.best_estimator_.predict(x_test)

# %%
r2_score(y_test, clf_pred)
# Out:
# 0.8846293508858245

# %% [markdown]
# Our model learnt Almost 89% .

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(clf.best_estimator_,"PJ7_Flight.obj")
RF_from_joblib=joblib.load('PJ7_Flight.obj')
Predicted = RF_from_joblib.predict(x_test)
Predicted
# Out:
# array([10797.78      ,  9993.50666667, 12450.56      , ...,
#         7825.0232381 ,  9324.87015876,  4843.35      ])

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.DataFrame([RF_from_joblib.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                0            1         2        3        4        5     \
# Predicted  10797.78  9993.506667  12450.56  3317.78  6529.39  6030.78
# Original    5567.00  8372.000000  12898.00  3210.00  6093.00  5073.00
#
#                6             7       8         9        10      11       12    \
# Predicted  13330.97  12091.624589  8539.2  14660.11  7236.87  5177.6  6215.36
# Original   13663.00  13504.000000  9187.0  14781.00  7229.00  4668.0  5386.00
#
#                13        14        15            16      17      18      19    \
# Predicted  12385.55  10583.61  16827.89  11869.596853  3349.8  5054.4  6859.0
# Original   12395.00  11410.00  15025.00  11668.000000  4392.0  5613.0  8040.0
#
#                    20           21       22       23           24    \
# Predicted  11196.602042  7176.045798  7776.91  5955.58  7759.290333
# Original    9001.000000  5126.000000  7832.00  6961.00  8851.000000
#
#                   25        26       27           28        29       30    \
# Predicted  4598.844024   9335.87  5434.66  4748.796797  13376.03  5973.13
# Original   4823.000000  10203.00  5228.00  4823.000000  13364.00  5963.00
#
#               31           32       33       34       35       36        37    \
# Predicted  9703.81  6932.026667  8464.33  12898.0  7236.87  12898.0   9194.92
# Original   8147.00  6860.000000  6795.00  12898.0  7229.00  12898.0  10696.00
#
#                   38        39           40      41           42         43    \
# Predicted  4711.950588  12697.69  9555.153802  5462.4  4348.247136  16147.085
# Original   4804.000000  11467.00  8601.000000  5201.0  4174.000000  16289.000
#
#               44       45           46       47         48         49    \
# Predicted  5926.32  7370.66  3670.836833  15123.6  14812.715  11759.859
# Original   6934.00  7229.00  3597.000000  15129.0  15129.000   7198.000
#
#                   50       51          52         53       54      55    \
# Predicted  9020.562941  3841.86  12207.3575  12584.134  5352.91  7064.0
# Original   6513.000000  3841.00   9417.0000  12646.000  4544.00  7064.0
#
#                56           57       58        59           60       61    \
# Predicted  8676.465  9595.259357  11070.5  11394.61  4256.385579  8023.62
# Original   8728.000  6645.000000  11087.0   9134.00  4488.000000  7258.00
#
#               62       63            64       65           66       67    \
# Predicted  5289.39  17137.1  10712.743333  3808.53  11959.02185  5825.59
# Original   4544.00  17261.0  10441.000000  3807.00  12093.00000  4483.00
#
#                    68       69       70       71        72       73    \
# Predicted  11613.282346  3572.33  6780.02  4651.65  10611.69  9156.25
# Original    7198.000000  2754.00  5601.00  4050.00  10844.00  8586.00
#
#                74           75       76       77       78        79    \
# Predicted  11850.45  8035.022113  9428.83  17412.7  13008.1  10191.07
# Original   11213.00  6953.000000  9968.00  16775.0  13044.0  14871.00
#
#                   80           81        82           83           84    \
# Predicted  4595.323152   9806.11073  13009.32  8334.454941  6331.823333
# Original   4804.000000  10678.00000  13029.00  9100.000000  6314.000000
#
#               85           86        87      88            89       90    \
# Predicted  6281.88  6824.220861  16737.04  3666.1  12004.903333  4876.41
# Original   6195.00  6818.000000  16274.00  3332.0  11793.000000  4145.00
#
#               91       92            93           94       95        96    \
# Predicted  3925.37  6335.13  17168.238333  9189.281776  3694.08  14180.01
# Original   5725.00  6093.00  17493.000000  8018.000000  3543.00  13941.00
#
#                  97        98       99      100      101       102      103   \
# Predicted  15753.1325  15462.29  7348.44  6780.1  6553.87  16319.75  2435.24
# Original   18752.0000  17057.00  7229.00  6069.0  6494.00  16704.00  2647.00
#
#               104      105      106      107         108      109   \
# Predicted  6502.73  9309.58  3874.55  4948.18  8268.96319  9591.26
# Original   5797.00  9345.00  3847.00  5575.00  6795.00000  6117.00
#
#                   110      111      112       113          114       115   \
# Predicted  6725.493929  6260.98  5050.97  12298.98  9187.055651  10168.43
# Original   7514.000000  6412.00  4823.00   7295.00  9627.000000   9663.00
#
#                116     117          118      119       120       121   \
# Predicted  13557.37  4226.0  9508.282358  8021.25  16814.14  14715.61
# Original   14151.00  4226.0  8073.000000  8016.00  18485.00  14714.00
#
#                    122          123           124       125        126   \
# Predicted  12520.187238  5928.151667  10471.453333  18636.86  13857.935
# Original   13217.000000  6144.000000  11200.000000  19595.00  14388.000
#
#               127       128      129      130        131      132      133   \
# Predicted  6707.53  10776.71  3463.61  3576.62  14051.635  10262.0  3814.03
# Original   6069.00  15190.00  3100.00  3543.00  13759.000  10262.0  7120.00
#
#                134      135     136       137      138           139   \
# Predicted  13955.31  4009.89  3936.1  10430.74  7087.53  11695.453127
# Original   13067.00  4319.00  3873.0  10844.00  7690.00  12192.000000
#
#                140      141      142      143      144       145   \
# Predicted  13145.86  7836.91  14776.8  3525.83  11111.2  10163.36
# Original   12739.00  7662.00  14781.0  2754.00  12373.0  11134.00
#
#                    146       147          148      149       150      151   \
# Predicted  10711.651111  13444.31  6004.294286  3881.51  14952.59  8835.63
# Original   10406.000000  13014.00  6038.000000  4049.00  15135.00  8452.00
#
#                152      153      154      155      156       157      158   \
# Predicted  14373.29  9007.34  3581.86  11602.3  5140.71  14305.73  2958.77
# Original   12475.00  6959.00  3419.00  10262.0  5232.00  14781.00  2754.00
#
#                   159       160      161      162      163       164   \
# Predicted  13120.16125  10813.84  6036.01  4056.35  4948.18  11400.69
# Original   11667.00000  12384.00  5947.00  4049.00  3925.00  12284.00
#
#                165       166       167      168      169      170   \
# Predicted  14746.78  5899.518  16284.48   9840.9  13533.5  9287.81
# Original   19644.00  6205.000  16289.00  13542.0   9400.0  9345.00
#
#                   171      172          173          174          175   \
# Predicted  4396.928679  7709.07  8148.799333  4369.004333  6334.067143
# Original   4077.000000  8016.00  7791.000000  4911.000000  7416.000000
#
#                    176     177       178      179     180          181   \
# Predicted  14321.203068  2426.5  3951.903  7625.84  3278.2  4364.236057
# Original   14300.000000  2385.0  6722.000  6253.00  4392.0  3943.000000
#
#                182         183           184       185      186      187   \
# Predicted  4446.304  13174.8848  13473.256667  13149.59  8574.39  4547.18
# Original   4409.000  12547.0000  14960.000000  12692.00  7980.00  4145.00
#
#               188          189     190       191       192      193     194   \
# Predicted  8540.92  7420.331639  7229.0  14332.65  12425.16  6424.46  7011.9
# Original   8366.00  7503.000000  7229.0  14781.00  13912.00  6838.00  7228.0
#
#               195       196      197      198           199      200     201   \
# Predicted  14240.2  10483.38  3907.61  6268.41  13914.378259  9811.54  5678.0
# Original   14231.0  11507.00  3841.00  6117.00  15170.000000  8586.00  5678.0
#
#               202          203           204          205     206      207   \
# Predicted  5420.29  6107.562667  12651.252844  6876.938353  6724.1  9351.19
# Original   5406.00  6027.000000  13465.000000  6979.000000  6094.0  8586.00
#
#                208        209       210      211      212     213      214   \
# Predicted  15122.73  10738.394  14616.14  3620.42  9486.79  3687.0  3313.64
# Original   18286.00  15407.000  13344.00  3573.00  8066.00  3687.0  3603.00
#
#                   215       216          217       218       219   \
# Predicted  9133.807167  14747.87  7767.329167  6596.515  11326.04
# Original   8855.000000  14781.00  8834.000000  6600.000  11134.00
#
#                   220      221      222          223          224   \
# Predicted  4464.589333  5139.93  3576.54  4155.489167  4407.436808
# Original   4991.000000  5613.00  3543.00  4174.000000  4423.000000
#
#                   225      226      227           228           229   \
# Predicted  12249.57643  6635.91  7394.36  11536.231754  10728.074231
# Original   15058.00000  6416.00  6427.00  14629.000000   7740.000000
#
#                   230          231       232      233      234          235   \
# Predicted  4187.238721  4809.716716  14542.82  2595.76  12863.0  4845.434525
# Original   3898.000000  4804.000000  13941.00  2647.00   6092.0  4804.000000
#
#                   236      237          238       239       240       241   \
# Predicted  4513.349172  3178.75  4135.742203  15906.19  13643.92  10275.65
# Original   4423.000000  3210.00  3943.000000  14815.00  13759.00  10262.00
#
#                   242      243           244      245       246       247   \
# Predicted  4067.014833  6959.99  13707.463333  5228.07  6851.664  15893.43
# Original   4482.000000  7189.00  13587.000000  4812.00  5932.000  15554.00
#
#               248        249      250      251     252           253   \
# Predicted  9590.96  10578.625  4662.56  2360.71  3651.8  13687.357624
# Original   9899.00  10368.000  4423.00  2227.00  3543.0  13882.000000
#
#                254      255       256         257       258        259   \
# Predicted  12385.55  9461.88  13191.28  4542.01276  13730.49  13321.425
# Original   12395.00  8759.00  13626.00  4423.00000  14083.00  13014.000
#
#                260      261          262      263          264        265   \
# Predicted  13833.64  3861.65  4192.636667  7123.84  9961.742807  10873.165
# Original   13941.00  3841.00  4460.000000  7064.00  7618.000000  12327.000
#
#                   266       267           268       269      270   \
# Predicted  7328.568333  10829.77  10977.360305   9178.88  7507.56
# Original   7608.000000  10844.00   9443.000000  15704.00  5608.00
#
#                   271      272      273      274      275          276   \
# Predicted  4072.191324  2123.62  6852.56  3479.47  9859.72  15170.34375
# Original   3597.000000  2017.00  6853.00  2754.00  8372.00  15129.00000
#
#              277      278      279          280           281     282   \
# Predicted  7229.0  4896.54  9109.76  5096.299231  10746.925893  5823.8
# Original   7229.0  4878.00  7438.00  4268.000000  10975.000000  6976.0
#
#                   283      284      285           286       287       288   \
# Predicted  9491.763706  7479.42  9269.13  13802.251467  10453.86  10262.84
# Original   7154.000000  5678.00  8452.00  13817.000000  12940.00   7295.00
#
#                   289      290        291          292       293       294   \
# Predicted  4727.324616  4872.57  15366.585  8535.821812  12741.31  13802.52
# Original   4804.000000  5944.00  15554.000  7575.000000  12692.00  13067.00
#
#                    295      296        297          298       299   \
# Predicted  13900.692991  7135.34  13801.296  4137.736919  11722.16
# Original   14300.000000  6152.00  13014.000  3943.000000  12383.00
#
#                   300     301           302      303           304      305   \
# Predicted  8137.932222  4732.5  13794.953333  5682.99   9013.183333  12341.1
# Original   8372.000000  4859.0  14571.000000  5298.00  11050.000000  12395.0
#
#                   306          307      308       309         310     311   \
# Predicted  4111.083529  5052.033333  8870.03  4359.767  9381.25769  4995.0
# Original   4423.000000  3782.000000  8085.00  3383.000  9103.00000  4050.0
#
#               312       313       314          315       316          317   \
# Predicted  7761.67  8628.735  14551.04  4122.689941  10364.92  9596.918394
# Original   5608.00  8352.000  15654.00  3943.000000  10031.00  7695.000000
#
#                318      319           320          321        322       323   \
# Predicted  10203.16  5436.87  11521.297714  4431.890919  13975.925  11643.33
# Original   11077.00  5406.00  11642.000000  4423.000000  14237.000  10262.00
#
#                 324     325       326       327          328      329   \
# Predicted  15782.395  6505.3  12241.96  11101.46  14103.21125  4259.67
# Original   15603.000  8542.0  11642.00  11087.00  13381.00000  4145.00
#
#               330           331      332      333       334      335   \
# Predicted  4499.94  10193.151429  4512.95  8878.29  10729.41  12755.8
# Original   4030.00   9653.000000  4885.00  9663.00  10844.00  13348.0
#
#                336      337      338       339      340      341     342   \
# Predicted  10234.97  7606.76  8292.71  10245.24  4085.91  6491.62  6840.0
# Original   10844.00  8016.00  7804.00  10262.00  3873.00  6442.00  5883.0
#
#                343       344      345      346       347       348       349   \
# Predicted  5951.039  14173.64  14789.6  3986.56  14425.02  15854.59  14621.82
# Original   5694.000  14231.00  14714.0  3384.00  14571.00  14815.00  14781.00
#
#                350       351       352           353           354   \
# Predicted  14442.16  10721.79  14503.01  13356.880333  10713.759191
# Original   14781.00  10844.00  14714.00  12224.000000   9385.000000
#
#                   355      356          357      358       359          360   \
# Predicted  8116.512222  8084.88  3803.274631  7045.11  14720.96  4229.434533
# Original   9021.000000  8040.00  3398.000000  6144.00  14714.00  3943.000000
#
#               361       362      363       364          365      366   \
# Predicted  10262.0  8333.717  10262.0  10769.44  5863.563333  4971.62
# Original   10262.0  7485.000  10262.0  10844.00  5409.000000  5830.00
#
#                   367      368      369      370          371           372   \
# Predicted  4776.505768  14664.7  6023.47  6976.57  8240.523333  15517.157273
# Original   4174.000000  15129.0  5021.00  6223.00  9412.000000  15147.000000
#
#                373       374          375     376          377       378   \
# Predicted  14166.45  6936.603  4652.925217  5812.2  4642.844024  13944.74
# Original   15129.00  4545.000  3858.000000  4959.0  4823.000000  11848.00
#
#                 379        380       381       382          383      384   \
# Predicted  5080.0275  4829.9425  14082.91  10245.24  6119.963333  10262.0
# Original   5403.0000  4945.0000  14388.00  10262.00  5228.000000  10262.0
#
#               385      386           387          388      389           390   \
# Predicted  7716.47  6353.85   9008.614848  5697.071986  9941.58  11856.482963
# Original   6902.00  4563.00  16259.000000  7295.000000  7931.00  13259.000000
#
#                    391     392      393      394      395       396      397   \
# Predicted  13565.119167  6728.3  3911.17  6598.08  7508.67  11107.72  6700.21
# Original   13882.000000  6412.0  3847.00  6017.00  6943.00  11507.00  6206.00
#
#               398      399      400      401      402           403      404   \
# Predicted  3841.65  11982.0  4403.18  8397.75  4776.22  13378.341528  7575.72
# Original   3841.00  11982.0  4423.00  8372.00  4544.00  13381.000000  7064.00
#
#                   405      406      407      408      409     410       411   \
# Predicted  3722.830119  4081.59  14974.4  4898.32  9136.18  3438.0  13679.29
# Original   4632.000000  4392.00  14714.0  4030.00  8505.00  3383.0  12284.00
#
#                   412       413      414      415     416      417      418   \
# Predicted  4995.811024  11046.34  7614.36  12898.0  7822.7  9202.68  4618.05
# Original   5694.000000  12125.00  8147.00  11924.0  8040.0  9345.00  4995.00
#
#                419     420          421       422          423         424   \
# Predicted  13381.61  3536.8  3991.470679  13401.28  4141.536667  7588.29741
# Original    9732.00  4319.0  4077.000000  12835.00  3873.000000  7005.00000
#
#               425          426       427       428      429          430   \
# Predicted  11240.2  13675.28125  14864.97  13725.64  8247.91  4825.936407
# Original    6838.0  14431.00000  15129.00  13817.00  8452.00  4823.000000
#
#                431          432       433       434     435           436   \
# Predicted  10248.97  6984.508889  11984.95  14260.46  6524.6  12047.177542
# Original    7757.00  6979.000000  13994.00  14939.00  5058.0  12327.000000
#
#                437      438          439          440       441       442   \
# Predicted  13406.03  5436.87  3923.497439  4342.949169  16548.98  10528.79
# Original   13376.00  5406.00  3540.000000  4423.000000  18804.00   8586.00
#
#               443      444       445      446     447        448       449   \
# Predicted  7969.02  10262.0  13079.56  2037.88  4045.8  9379.3525  13840.91
# Original   8016.00  10262.0  10953.00  1965.00  4050.0  9187.0000  14151.00
#
#                    450       451          452      453           454   \
# Predicted  14135.171369  14525.79  6789.145048  2569.82  12860.949231
# Original   15147.000000  14714.00  4777.000000  2753.00  13587.000000
#
#                    455           456           457      458     459      460   \
# Predicted   9987.350237  13305.179507  11227.701597  3543.06  7229.0  9555.43
# Original   13587.000000  13376.000000  10197.000000  3807.00  7229.0  8064.00
#
#                461       462       463       464      465       466   \
# Predicted  10748.11   6537.12  10445.08  15124.28  6976.57  14439.56
# Original   12524.00  14053.00  10368.00  15129.00  6223.00  16352.00
#
#                    467           468       469      470     471       472   \
# Predicted  13579.417318  11284.025463  10030.09  4238.71  4382.4  14601.21
# Original   13376.000000   7354.000000  12677.00  3597.00  4319.0  14571.00
#
#                473          474      475           476           477   \
# Predicted   8081.87  9067.334629  2198.09  12810.950556  13547.824862
# Original   12384.00  9315.000000  1759.00  12534.000000  13376.000000
#
#                478       479          480           481           482   \
# Predicted  14465.96  10230.32  13620.56343  12641.428824  11613.282346
# Original   13941.00  10441.00  22096.00000  13243.000000  13377.000000
#
#               483      484      485      486           487       488   \
# Predicted  5379.57  5176.73  12898.0  3682.88  14972.207679  5580.685
# Original   6015.00  4030.00  12898.0  3543.00  15411.000000  5403.000
#
#                489       490          491        492       493     494   \
# Predicted  10378.47  10786.59  4801.803152  17096.615  15039.48  3914.4
# Original   10844.00  10703.00  4804.000000  16914.000  15129.00  3841.0
#
#               495           496       497          498      499          500   \
# Predicted  7236.87  10905.244127  14508.85  4900.914158  10844.0  3893.431297
# Original   7229.00  10975.000000  14231.00  4804.000000  10844.0  3398.000000
#
#                    501       502      503      504       505         506   \
# Predicted  10410.082684   9241.01  11087.0  7438.92   8978.27  7703.04125
# Original    9001.000000  10348.00  11087.0  7832.00  10031.00  4284.00000
#
#              507       508      509           510       511      512   \
# Predicted  4710.0  10572.84  3531.42   9194.075714  5976.678  12388.7
# Original   4668.0  10262.00  3100.00  14871.000000  5694.000  12395.0
#
#               513           514       515       516       517      518   \
# Predicted  3934.96  14271.971429  14005.16  10265.15  13073.69  9354.82
# Original   3841.00  14571.000000  13227.00  10262.00  13029.00  7341.00
#
#               519      520          521       522      523           524   \
# Predicted  10294.4  6570.46  9541.851722  14211.18  3179.04  11902.635175
# Original   10262.0  6270.00  9646.000000  14178.00  3100.00  14323.000000
#
#                  525      526           527      528     529          530   \
# Predicted  11284.3495  8852.48  13397.113333  7714.09  5678.0  3600.289167
# Original   10877.0000  9663.00  10953.000000  7832.00  5678.0  3597.000000
#
#                531       532      533          534      535     536      537   \
# Predicted  13667.86  12131.43  9007.69  4236.112046  6456.23  4205.7  3824.54
# Original   18797.00  15809.00  8005.00  3943.000000  6451.00  4435.0  4107.00
#
#                538      539      540      541          542           543   \
# Predicted  14473.63  2799.39  3640.91  17412.7  4274.517381  13654.533333
# Original   14781.00  2754.00  4423.00  15288.0  3943.000000  14571.000000
#
#                544          545         546      547          548     549   \
# Predicted  13810.03  13608.62375  4014.08817  6500.33  6212.044167  6247.8
# Original   14388.00  12819.00000  3419.00000  6442.00  4441.000000  6068.0
#
#                550           551          552      553         554      555   \
# Predicted  13772.58  14206.091667  7585.098524  5926.09  14335.3845  3257.04
# Original   14151.00  13873.000000  7530.000000  7202.00  14571.0000  2754.00
#
#               556      557       558       559     560       561      562   \
# Predicted  5316.62  3915.63  12763.58  10816.89  4976.1  14032.39  9458.65
# Original   5831.00  5201.00  12475.00  10844.00  4995.0  14120.00  9899.00
#
#                   563       564      565       566      567      568   \
# Predicted  6931.480889  11348.26  11982.0  13833.24  4145.41  5074.34
# Original   7738.000000  15284.00  11982.0  13843.00  4319.00  5403.00
#
#                   569       570      571       572      573      574   \
# Predicted  4991.631855   9007.37  13424.2  16119.15  4931.11  4376.68
# Original   4804.000000  12677.00  13376.0  16079.00  4544.00  4995.00
#
#                575         576       577          578       579          580   \
# Predicted  11874.61  4752.54927  14425.77  4398.611996  12166.51  4599.439885
# Original   11262.00  4823.00000  13941.00  4148.000000  12373.00  4174.000000
#
#                581      582      583           584      585      586   \
# Predicted  13959.23  7847.38  4522.37   9246.779838  10262.0  8809.68
# Original   14151.00  7258.00  5515.00  13587.000000  10262.0  8844.00
#
#                587      588      589          590     591      592       593   \
# Predicted  9724.469  4464.85  5238.06  4753.190732  3882.0  8540.34  13309.32
# Original   9646.000  4282.00  5198.00  4823.000000  3841.0  8529.00  12898.00
#
#               594       595       596      597      598          599   \
# Predicted  3939.75  11793.67  12413.23  12332.9  8855.15  13119.84892
# Original   3210.00  13029.00  12284.00  12373.0  8669.00  13014.00000
#
#                   600      601      602     603           604      605   \
# Predicted  3874.439058  12939.8  3636.54  8037.0  10804.004964  5881.01
# Original   3540.000000  13029.0  3597.00  8541.0  11222.000000  6582.00
#
#                606      607       608        609      610          611   \
# Predicted  11335.82  3206.28  15188.38  6730.8785  2442.59  9038.430422
# Original   11465.00  3100.00  15318.00  7144.0000  2385.00  9103.000000
#
#                   612          613      614           615      616   \
# Predicted  3649.346963  12500.79575  3778.28   8958.511147  9748.44
# Original   3597.000000  11269.00000  4995.00  14067.000000  6117.00
#
#                   617       618       619     620       621         622   \
# Predicted  4292.210738   9855.78  13624.15  9160.7  16948.04  19482.7275
# Original   4423.000000  10203.00  13584.00  8586.0  17024.00  21375.0000
#
#               623      624          625      626      627      628   \
# Predicted  6222.23  5427.79  4811.828811  3860.45  5929.96  8843.43
# Original   6104.00  7486.00  4804.000000  3841.00  6297.00  7870.00
#
#                    629       630       631      632          633      634   \
# Predicted  11513.642368  12483.13  13191.28  7591.02  5471.859333  8974.45
# Original   12717.000000   6916.00  13626.00  8016.00  4729.000000  8603.00
#
#              635       636       637          638          639      640   \
# Predicted  6274.9  14750.89  12735.47  9218.065649  7981.912841  6369.81
# Original   5963.0  14960.00  10991.00  8625.000000  6723.000000  6934.00
#
#                641          642           643       644          645   \
# Predicted  4365.729  6847.702571  12891.372545  13401.09  4603.754599
# Original   5644.000  6381.000000  13727.000000  14151.00  4804.000000
#
#               646          647      648          649       650       651   \
# Predicted  2554.16  7107.910524  4423.93  4891.100339  12065.48  7266.415
# Original   2050.00  7198.000000  4995.00  4632.000000  10067.00  7276.000
#
#                    652       653      654     655      656           657   \
# Predicted  13088.296152  11865.03  4349.53  8016.0  5234.66  11496.500667
# Original   13014.000000  11432.00  3100.00  8016.0  5201.00  14067.000000
#
#                   658      659      660           661      662      663   \
# Predicted  7486.924381  7729.85  3564.68  14592.222917  9392.73  3840.22
# Original   6144.000000  7832.00  3543.00  14924.000000  8372.00  3841.00
#
#                 664       665      666     667          668          669   \
# Predicted   9705.049  10816.22  7244.74  5421.9  8401.494921  4109.869167
# Original   10929.000  10844.00  7229.00  5403.0  6076.000000  4842.000000
#
#               670          671      672           673      674      675   \
# Predicted  10470.8  4296.752154  8532.62  13103.898824  14764.4  6576.21
# Original   10539.0  3847.000000  8529.00  14424.000000  14714.0  5647.00
#
#                676           677       678       679         680   \
# Predicted  10806.25  12556.588091  16272.28  12985.57  8713.08509
# Original   10844.00  12778.000000  20904.00  13381.00  6883.00000
#
#                   681          682          683           684      685   \
# Predicted  3719.322333  3492.933333  8145.235889  13375.774667  7558.94
# Original   3597.000000  5780.000000  6270.000000  13292.000000  8040.00
#
#                   686       687       688       689      690          691   \
# Predicted  4439.585169   9350.33  6645.138  14223.72  7093.61  4497.408541
# Original   4462.000000  12351.00  6442.000  12649.00  6628.00  4239.000000
#
#               692      693     694       695     696           697      698   \
# Predicted  8989.29  13850.8  4331.4  10455.33  5064.8  15021.974333  5806.56
# Original   8355.00  14178.0  3943.0  15318.00  5000.0  15078.000000  5636.00
#
#                699      700      701      702          703       704   \
# Predicted  10390.34  16736.0  14589.9  6411.16  4704.077947  10442.59
# Original   15318.00  16736.0  14571.0  6741.00  5224.000000  10919.00
#
#                705      706       707           708       709      710   \
# Predicted  10808.57  3494.45  14462.64  14520.581429  10419.52  5610.24
# Original   10844.00  3332.00  14781.00  14781.000000   8603.00  3359.00
#
#               711           712       713      714          715       716   \
# Predicted  5872.18   9589.396052  11982.94  5240.09  8981.075557  14622.22
# Original   6478.00  10161.000000  10703.00  5228.00  8266.000000  14781.00
#
#                    717       718      719     720      721          722   \
# Predicted  12150.793083  10276.76  8500.95  3491.6  6300.85  4784.450732
# Original   15428.000000  10262.00  8529.00  2754.0  5796.00  4823.000000
#
#              723          724     725       726          727      728   \
# Predicted  6325.2  7697.872508  7064.0  12323.34  4075.399464  11982.0
# Original   6151.0  7005.000000  7064.0  13152.00  3943.000000  11982.0
#
#                    729        730           731      732          733   \
# Predicted  11792.110833  4296.2285  10066.322974  7479.75  4110.807821
# Original   15318.000000  4174.0000  13727.000000  8565.00  3847.000000
#
#               734       735      736           737      738        739   \
# Predicted  10262.0  13835.17  6268.47  11867.131667  13029.0  13648.945
# Original   10262.0  14815.00  6093.00  11753.000000  13029.0  13067.000
#
#                   740        741          742       743      744      745   \
# Predicted  7092.164426  6656.5125  4502.404616  10265.15  6145.89  7265.73
# Original   7144.000000  6745.0000  4174.000000  10262.00  6496.00  7229.00
#
#                    746      747      748     749       750       751   \
# Predicted  12565.838889  4359.95  6163.45  8933.4  10656.01  5154.436
# Original   11602.000000  4174.00  6587.00  8452.0  10844.00  4273.000
#
#               752       753       754     755        756       757       758   \
# Predicted  5679.97  12963.97  22251.94  5678.0  4786.9825  14059.53  15148.17
# Original   5158.00  12692.00  22270.00  5678.0  5694.0000  13584.00  16022.00
#
#                  759       760          761          762           763   \
# Predicted  17844.8525  15715.97  9305.438333  8978.223858  10547.614152
# Original   14815.0000  11647.00  8839.000000  9103.000000   9863.000000
#
#                   764       765       766       767      768           769   \
# Predicted  5496.833333  11606.08  13276.14  14535.55  12898.0  13507.568667
# Original   6069.000000  10975.00  14151.00  13941.00  12898.0  13014.000000
#
#               770      771       772       773          774      775   \
# Predicted  6955.59  6486.42  12759.18   7420.94  4784.793152  13881.9
# Original   7657.00  6451.00  12576.00  13611.00  4804.000000  14151.0
#
#                   776      777      778       779       780       781   \
# Predicted  12012.42625  7236.87  5493.38  13662.76   8687.33  10365.89
# Original   11552.00000  7229.00  6937.00  12616.00  11260.00  10919.00
#
#              782       783          784           785     786      787   \
# Predicted  2007.5   6645.39  4081.449451  13716.583035  7483.4  14610.9
# Original   1965.0  10231.00  3749.000000  13882.000000  7832.0  14571.0
#
#               788      789      790          791           792     793   \
# Predicted  2306.81  3691.67  4530.74  9247.386101  10538.054444  5364.8
# Original   2227.00  3383.00  3687.00  9315.000000  10907.000000  5277.0
#
#                794      795           796       797      798       799   \
# Predicted  12928.04  7289.19  13705.887624  10899.83  7714.57  10394.61
# Original   12692.00  7229.00  13882.000000  10844.00  6752.00  10262.00
#
#                 800      801          802       803       804          805   \
# Predicted   7404.395  2578.36  11849.84549  14898.35  13194.54  3981.889952
# Original   12415.000  2753.00  14323.00000  12284.00  13014.00  4239.000000
#
#                    806          807           808      809     810       811   \
# Predicted  12365.388527  7082.089286  14494.391429  6595.57  7046.5  12761.69
# Original   12392.000000  6587.000000  13731.000000  6416.00  7258.0  12681.00
#
#                   812          813       814      815      816      817   \
# Predicted  5994.529167  3600.289167  7684.055  3838.78  8964.69  5484.23
# Original   5092.000000  3597.000000  7480.000  3100.00  9663.00  5510.00
#
#                   818       819      820       821       822          823   \
# Predicted  7921.310833  4163.822  8852.08  10734.21  10876.26  5376.214664
# Original   6643.000000  4591.000  9663.00   9923.00  10929.00  4804.000000
#
#                    824       825      826      827       828         829   \
# Predicted  11290.429167  7053.162  10262.0  8716.33  16312.44  7836.72119
# Original    9483.000000  6171.000  10262.0  8085.00  16289.00  6860.00000
#
#               830       831      832      833       834       835       836   \
# Predicted  7123.84  14851.58  11087.0  4424.63  10876.84  16320.75  11959.53
# Original   7064.00  14714.00  11087.0  4174.00   9314.00  16704.00  11003.00
#
#               837      838         839      840       841      842     843   \
# Predicted  5329.56  7236.87   9473.8775  6689.41  16288.04  6907.97  5475.8
# Original   5198.00  7229.00  10454.0000  7934.00  16376.00  8666.00  5613.0
#
#               844          845      846          847       848      849   \
# Predicted  7834.28  3683.831651  2236.88  7758.424143  10571.69  6539.69
# Original   8529.00  3858.000000  1965.00  6795.000000   7530.00  4441.00
#
#               850      851      852     853          854      855       856   \
# Predicted  9666.05  12898.0  6461.28  5646.6  4719.374978  4374.17  11256.36
# Original   8586.00  12898.0  6037.00  5613.0  5224.000000  4049.00  11733.00
#
#                   857      858     859      860           861       862   \
# Predicted  7836.129286  4352.01  2258.5  9493.36  10893.131667  16424.28
# Original   6612.000000  3971.00  2227.0  8586.00  10919.000000  16263.00
#
#               863       864          865       866           867       868   \
# Predicted  3709.23  15562.13  5947.073333  16104.47  15837.473667  10838.91
# Original   3859.00  12371.00  5073.000000  16079.00  15135.000000  11087.00
#
#                   869       870       871     872         873           874   \
# Predicted  5317.111667  16974.23  10794.54  6289.5  11233.1775  13401.719257
# Original   5458.000000  17234.00  10844.00  6741.0  12410.0000  13376.000000
#
#              875           876       877          878          879   \
# Predicted  7511.4  12924.232157  14502.33  5058.898167  9540.028713
# Original   7657.0  13033.000000  14571.00  5618.000000  9646.000000
#
#                    880          881      882           883       884   \
# Predicted  12514.303333  6861.121429  4085.12  12495.075571  12736.88
# Original   13349.000000  6416.000000  3873.00  14687.000000  10953.00
#
#               885          886       887          888           889   \
# Predicted  9312.84  4646.650338  10164.93  7930.680833  10068.407324
# Original   8452.00  5740.000000   6197.00  9270.000000  11789.000000
#
#                   890           891        892      893       894      895   \
# Predicted  7176.045798  12004.876667  14350.725  5934.55  6524.095  5396.71
# Original   7110.000000  14221.000000  14571.000  7229.00  6093.000  5895.00
#
#                896           897       898      899          900       901   \
# Predicted  14248.32  13695.161818  14177.75  2400.56  3964.522116  13011.74
# Original   14781.00  13882.000000  13941.00  2227.00  3850.000000  13044.00
#
#               902      903       904      905           906      907   \
# Predicted  4448.51  3317.78  15595.88  7265.73  13276.866238  4223.34
# Original   4483.00  2759.00  15029.00  7229.00  14897.000000  4880.00
#
#                  908      909       910      911     912      913      914   \
# Predicted  10776.0125  4373.16  10835.87  6304.33  9314.3  6057.96  6582.55
# Original   10368.0000  3807.00  10844.00  4851.00  8529.0  6094.00  7229.00
#
#               915       916      917       918       919     920       921   \
# Predicted  9796.28  13697.86  8031.34  10442.59  12843.08  5172.0  10491.88
# Original   8586.00  12284.00  8040.00  10919.00  10675.00  5613.0  12192.00
#
#                922          923       924      925       926      927   \
# Predicted  14227.33  8478.820357  4437.038  7395.81  13476.64  3970.75
# Original   10624.00  7575.000000  4107.000  6103.00  13376.00  3859.00
#
#                928         929       930      931        932       933   \
# Predicted  14060.98  10192.6175  11545.11  4939.46   5777.998  13372.55
# Original   13941.00  10676.0000  11392.00  5198.00  11598.000  13941.00
#
#               934          935     936      937       938         939   \
# Predicted  10796.7  5930.772143  9828.6  8524.96  12409.14  12077.5775
# Original   11118.0  6121.000000  9663.0  8610.00  12284.00  12173.0000
#
#              940          941      942           943      944      945   \
# Predicted  9279.9  8388.088333  4691.03   9249.226129  4189.33  4180.28
# Original   9899.0  8770.000000  3625.00  10877.000000  4460.00  4885.00
#
#                    946      947          948       949      950      951   \
# Predicted  11724.816667  7134.14  3595.819167  10290.36  4633.03  5436.32
# Original   11546.000000  7064.00  3597.000000  10262.00  4544.00  5198.00
#
#                952       953          954      955      956          957   \
# Predicted  12625.42  10509.09  7708.966667  9684.59  8492.76  7013.663783
# Original   12681.00  13377.00  8283.000000  9314.00  8996.00  7081.000000
#
#               958           959      960      961      962       963   \
# Predicted  5453.76  12133.791667  9414.32  5724.91  2324.84  11322.28
# Original   6121.00  16932.000000  9187.00  5769.00  2470.00  12898.00
#
#                964          965       966       967      968     969   \
# Predicted  14692.51  6516.291667  10497.82  4775.305  8190.24  8529.0
# Original   14714.00  6442.000000   9794.00  4148.000  8372.00  8529.0
#
#                970      971      972           973          974     975   \
# Predicted  13289.68  17287.2  3185.49  11079.151667  4827.762663  6115.3
# Original   13067.00  17234.0  3100.00   8937.000000  4990.000000  6593.0
#
#                    976       977          978         979       980      981   \
# Predicted  13647.986667  13710.32  4846.057055  13839.6848  13831.61  13050.9
# Original   14151.000000  12284.00  4804.000000  13817.0000  13759.00  14151.0
#
#                    982        983          984        985      986      987   \
# Predicted  11300.564504  13561.955  12865.95794  11926.345  4410.74  9678.32
# Original    9794.000000  13584.000  12961.00000  12723.000  4807.00  9870.00
#
#                    988           989          990          991      992   \
# Predicted  13099.552325  15128.292381  4761.753152  15170.34375  10262.0
# Original   13292.000000  10276.000000  4804.000000  15129.00000  10262.0
#
#                    993      994          995     996          997   \
# Predicted  10110.873424  8846.98  5769.796667  7229.0  7750.860222
# Original   10407.000000  9187.00  6121.000000  7229.0  8372.000000
#
#                   998      999       1000         1001     1002     1003  \
# Predicted  8249.409963  6184.16   8278.85  4795.004015  9535.61  5475.64
# Original   8371.000000  6383.00  10262.00  4823.000000  9796.00  5510.00
#
#               1004      1005         1006      1007          1008     1009  \
# Predicted  10262.0  3871.789  4808.888253  7008.284  11118.696296  5110.88
# Original   10262.0  3597.000  4804.000000  7480.000   9736.000000  4460.00
#
#                1010        1011         1012      1013     1014         1015  \
# Predicted  10179.38  14221.3025  4323.129667  10230.32  7755.98  7767.329167
# Original    8366.00  14571.0000  3527.000000  10441.00  9134.00  6643.000000
#
#                1016       1017         1018      1019         1020  \
# Predicted  16162.74  15147.905  13568.50413  10559.77  6815.878333
# Original   18371.00  15129.000  13376.00000  10844.00  6117.000000
#
#                    1021     1022     1023     1024         1025         1026  \
# Predicted  13505.649318  12095.3  12898.0  8745.59  4172.609393  8362.811667
# Original   13376.000000  10808.0  12898.0  7927.00  3943.000000  7480.000000
#
#               1027     1028          1029      1030     1031         1032  \
# Predicted  3920.86  5433.48  13409.858297  11384.56  6587.94  9067.334629
# Original   3873.00  5842.00  13376.000000   9069.00  6314.00  9794.000000
#
#                1033      1034         1035      1036         1037    1038  \
# Predicted   9314.26  14953.74  8205.057429  7506.764  9002.815208  4657.3
# Original   10203.00  14714.00  8285.000000  8907.000  7670.000000  4544.0
#
#                1039      1040     1041     1042       1043    1044      1045  \
# Predicted  12205.94  11028.37  4544.85  2579.52  9074.0555  5186.4  11991.02
# Original   13502.00  11087.00  3971.00  2227.00  8366.0000  5228.0  13848.00
#
#                    1046     1047      1048     1049         1050     1051  \
# Predicted  11745.202507  6389.27  7467.015  4933.21  4372.699653  3258.56
# Original   11789.000000  5192.00  6860.000  4565.00  4423.000000  3100.00
#
#                1052     1053     1054      1055    1056      1057     1058  \
# Predicted  10245.24  7347.05  4214.49  7443.245  6066.2  12954.97  3853.39
# Original   10262.00  7229.00  6300.00  7198.000  5117.0  12681.00  3841.00
#
#               1059     1060      1061     1062          1063         1064  \
# Predicted  5661.74  4867.16  14677.08  11087.0  12633.623333  12556.05052
# Original   6245.00  4667.00  14781.00  11087.0  11989.000000  12777.00000
#
#               1065         1066         1067     1068     1069     1070  \
# Predicted  12373.0  4239.719062  8886.350476  4056.35  8703.81  8998.74
# Original   12373.0  3898.000000  7174.000000  4049.00  9254.00  8665.00
#
#              1071     1072     1073     1074         1075          1076  \
# Predicted  5678.0  12387.7  7650.33  7390.28  5165.540815  12075.952333
# Original   5678.0  12373.0  6628.00  5013.00  5224.000000  11596.000000
#
#                   1077     1078        1079    1080          1081  \
# Predicted  15583.96875  5226.72  5269.96125  4049.0  16141.543333
# Original   16704.00000  4957.00  5277.00000  5755.0  10715.000000
#
#                   1082     1083         1084     1085         1086     1087  \
# Predicted  4121.804616  8967.17  5685.493333  10262.0  4767.440732  3099.64
# Original   7295.000000  8662.00  6565.000000  10262.0  4823.000000  2754.00
#
#               1088     1089     1090    1091     1092          1093     1094  \
# Predicted  3223.35  5527.29  6657.66  4880.1  3543.84   9811.372355  6079.13
# Original   2050.00  7080.00  6628.00  5613.0  3543.00  10877.000000  5583.00
#
#               1095      1096          1097     1098         1099         1100  \
# Predicted  6351.21  10135.47  11257.569482  4425.36  4860.274824  9166.362449
# Original   6704.00  10976.00  10991.000000  5198.00  5618.000000  9526.000000
#
#               1101      1102     1103      1104     1105     1106     1107  \
# Predicted  8572.68  10143.38  4289.44  14021.72  6216.72  3787.37  7808.06
# Original   9663.00   8767.00  4392.00  16372.00  5351.00  3480.00  8849.00
#
#                 1108      1109     1110         1111    1112    1113    1114  \
# Predicted  11088.075  12455.81  6897.52  8627.565122  5678.0  9103.6  9564.0
# Original   15812.000  12898.00  4886.00  7670.000000  5678.0  9663.0  9564.0
#
#               1115      1116     1117      1118     1119     1120      1121  \
# Predicted  10907.0  10589.35  9647.67  14729.48  5054.37  7604.38  10832.19
# Original   10844.0   9314.00  8586.00  15342.00  4823.00  7064.00  10844.00
#
#               1122     1123         1124      1125         1126     1127  \
# Predicted  9448.31  7981.57  4763.643333  12201.59  4536.655519  12898.0
# Original   9502.00  8028.00  5224.000000  12384.00  4462.000000  12898.0
#
#                    1128         1129     1130          1131      1132  \
# Predicted  13974.568333  7079.460914  6614.63  12291.763889  11115.59
# Original   14237.000000  6282.000000  6818.00  15078.000000  11087.00
#
#               1133       1134         1135      1136         1137     1138  \
# Predicted  8321.28   9962.685  4840.037521  10710.92  7143.786667  2076.64
# Original   7480.00  10676.000  4823.000000  12308.00  6528.000000  2175.00
#
#                1139         1140      1141        1142     1143     1144  \
# Predicted  10678.38  4802.234232  15171.53  11057.8605  7259.72  3161.28
# Original   10844.00  4823.000000  15129.00  10919.0000  7001.00  3625.00
#
#                   1145     1146    1147    1148         1149         1150  \
# Predicted  7048.488889  7952.04  4686.9  4995.0  4758.234286  4791.510758
# Original   9274.000000  8367.00  4668.0  4995.0  4804.000000  4823.000000
#
#                 1151      1152     1153     1154      1155    1156      1157  \
# Predicted  4347.5085  10272.51  5837.65  8617.95  10811.05  7528.3   6484.04
# Original   4174.0000  10262.00  5298.00  8366.00  11134.00  7229.0  11627.00
#
#                1158     1159         1160     1161    1162         1163  \
# Predicted  13417.25  7284.09  4333.488424  4328.97  9832.8  6487.002903
# Original   15957.00  7229.00  5198.000000  3687.00  8586.0  6007.000000
#
#                    1164     1165     1166      1167         1168     1169  \
# Predicted  11861.772954  6646.92  7881.51   9239.47  3706.336758  8706.93
# Original   11542.000000  5842.00  8040.00  14871.00  3540.000000  7770.00
#
#               1170     1171     1172          1173         1174    1175  \
# Predicted  5135.57  3841.55  9306.39  13123.033333  9873.481429  5430.3
# Original   5277.00  3841.00  9412.00  13067.000000  9653.000000  5403.0
#
#              1176          1177         1178    1179      1180     1181  \
# Predicted  7064.0  11511.382024  4179.535487  5678.0  10473.05  5954.08
# Original   7064.0  12436.000000  4174.000000  5678.0  10262.00  5021.00
#
#                   1182    1183      1184      1185      1186      1187  \
# Predicted  9725.077701  5678.0  14172.18  14585.04  10770.09  6112.869
# Original   7408.000000  5678.0  13843.00  15400.00  11134.00  5911.000
#
#                1188          1189    1190    1191     1192          1193  \
# Predicted   9918.56  12297.814157  4995.0  6703.8  10262.0  15049.185977
# Original   11936.00  11474.000000  4050.0  5397.0  10262.0  19332.000000
#
#                1194     1195      1196         1197     1198    1199     1200  \
# Predicted  10330.25  9800.68  13888.62  9037.016388  5402.61  8016.0  7232.75
# Original   10262.00  9663.00  13843.00  7858.000000  5069.00  8016.0  7174.00
#
#                  1201         1202      1203    1204    1205        1206  \
# Predicted  15286.3625  4310.472571  11134.02  5031.0  8529.0  17669.6625
# Original   15764.0000  3943.000000  11150.00  6121.0  8529.0  17024.0000
#
#                1207      1208      1209          1210          1211     1212  \
# Predicted   8928.02  12996.69  15063.65   7962.617529  12479.832531  5004.16
# Original   10031.00  13029.00  14714.00  12537.000000   8307.000000  4784.00
#
#               1213     1214      1215     1216     1217        1218      1219  \
# Predicted  5335.95  7092.19  16741.25  3830.06  2076.16  15156.5625  10223.37
# Original   5177.00  6327.00  16736.00  3311.00  1965.00  15129.0000  10844.00
#
#                   1220      1221     1222          1223      1224        1225  \
# Predicted  4822.860735   8857.11   9518.4  11551.299641  10124.26  15217.3125
# Original   4823.000000  10539.00  10844.0  12192.000000  10539.00  15129.0000
#
#                   1226         1227         1228     1229        1230  \
# Predicted  4701.681556  7834.128333  9406.283333  5478.45  10952.1043
# Original   4823.000000  7452.000000  9181.000000  5897.00   9646.0000
#
#               1231     1232     1233          1234     1235     1236  \
# Predicted  6296.04  7296.36  9144.58  12080.028529  6211.28  4488.36
# Original   6297.00  6451.00  9663.00  11386.000000  6442.00  3782.00
#
#                   1237          1238     1239    1240         1241       1242  \
# Predicted  7535.957143   7563.715696  7865.89  7064.0  9427.629262  11495.509
# Original   7690.000000  12537.000000  6674.00  7064.0  7408.000000  13377.000
#
#                    1243     1244     1245      1246         1247     1248  \
# Predicted  12032.682794  5367.84  4839.19  10505.87  4509.025833  4572.18
# Original   14323.000000  5406.00  7202.00   9663.00  4377.000000  3625.00
#
#                    1249     1250     1251       1252     1253     1254  \
# Predicted  10085.211934  7718.45  5242.35  15257.187  6305.25  4569.74
# Original   10197.000000  4227.00  5403.00  15411.000  6216.00  4409.00
#
#                1255      1256          1257     1258          1259     1260  \
# ...
# Predicted  12732.9  8041.751222  14024.19  7591.02  7178.658333  4767.93
# Original   14871.0  7480.000000  14178.00  8016.00  7480.000000  4804.00
#
#                2727     2728     2729          2730          2731    2732  \
# Predicted  9106.168  3942.12  3201.55  10811.563628  15247.633333  3358.3
# Original   8366.000  4384.00  4050.00   6795.000000  13838.000000  3175.0
#
#               2733      2734     2735       2736     2737     2738      2739  \
# Predicted  6568.24  12808.37  7927.13  11919.645  8042.25  5929.71  10319.68
# Original   7202.00  12681.00  7064.00  12273.000  8541.00  6749.00  10262.00
#
#                   2740      2741     2742     2743      2744          2745  \
# Predicted  4600.366819  12314.56  4673.25  9816.17  10200.95  12013.828245
# Original   4823.000000  12373.00  4804.00  6781.00  10844.00  14533.000000
#
#               2746         2747         2748     2749     2750      2751  \
# Predicted  3318.35  4819.164365  7223.960667  4607.47  6243.32  16736.61
# Original   2754.00  4804.000000  6860.000000  5621.00  7173.00  17024.00
#
#               2752          2753     2754         2755      2756         2757  \
# Predicted  6545.66  12502.302333  7378.25  4680.655744  12889.07  4707.469325
# Original   7048.00  13180.000000  6152.00  4804.000000  12692.00  4804.000000
#
#              2758          2759     2760    2761       2762         2763  \
# Predicted  7064.0  11807.136852  5551.75  7064.0  12775.512  6148.812143
# Original   7064.0  16092.000000  6347.00  7064.0  13067.000  5228.000000
#
#               2764     2765     2766         2767     2768     2769  \
# Predicted  4445.81  8844.41  4028.51  6959.354956  6445.05  4363.88
# Original   4622.00  8586.00  3943.00  7923.000000  5883.00  4050.00
#
#                    2770          2771         2772      2773     2774  \
# Predicted   8057.784667  13324.787941   8713.08509  13743.88  7096.22
# Original   12327.000000  13727.000000  12537.00000  13014.00  5117.00
#
#                2775     2776          2777     2778          2779     2780  \
# Predicted  13328.18  6911.11  11039.319127  3093.42  10245.328107  6144.61
# Original   13014.00  6961.00   9925.000000  3100.00  13587.000000  6027.00
#
#               2781     2782        2783        2784     2785         2786  \
# Predicted  19127.5  12898.0  10074.0955  14925.1425  3844.22  9172.997083
# Original    9623.0  12898.0   6117.0000  16704.0000  3873.00  8073.000000
#
#               2787     2788     2789     2790         2791         2792  \
# Predicted  12898.0  4415.34  9157.01  3399.67  4735.441399  9237.690357
# Original   12898.0  7082.00  8781.00  3100.00  4823.000000  9345.000000
#
#                   2793     2794          2795      2796      2797      2798  \
# Predicted  4143.588432  6796.08   8544.551635  13667.43   9439.98  8339.045
# Original   3419.000000  6643.00  10786.000000  13941.00  11410.00  6117.000
#
#                   2799     2800     2801         2802        2803  \
# Predicted  6471.363333  8459.85  3931.38  9157.483494  15252.8225
# Original   6838.000000  8529.00  3841.00  6148.000000  15129.0000
#
#                   2804      2805      2806     2807     2808     2809  \
# Predicted  6744.662667  14477.84  16106.25  6537.63  4340.68  9626.19
# Original   7520.000000  15107.00  16079.00  5583.00  4226.00  8620.00
#
#                2810          2811         2812         2813         2814  \
# Predicted  7848.244  13269.883988  14986.82925  4133.844167  5753.605333
# Original   7648.000  13764.000000  20416.00000  3384.000000  4377.000000
#
#               2815          2816     2817      2818    2819     2820  \
# Predicted  3253.59  10384.724017  14762.3  9286.054  8142.0  4578.61
# Original   2754.00   8266.000000  14714.0  8892.000  8016.0  4460.00
#
#                   2821       2822         2823      2824       2825  \
# Predicted  4805.026029   8980.135  7331.366667   8986.43  7849.4125
# Original   4804.000000  10703.000  8028.000000  13302.00  8738.0000
#
#                    2826     2827     2828      2829         2830     2831  \
# Predicted  13800.785083  3643.13  3830.92  12839.36  3914.652545  9798.17
# Original   16914.000000  4995.00  3807.00  12767.00  3858.000000  9663.00
#
#                2832      2833         2834         2835     2836      2837  \
# Predicted  9426.598  13354.82  4826.894158  6380.147768  8029.84  11822.04
# Original   8366.000  15136.00  4174.000000  6442.000000  8366.00   5118.00
#
#              2838      2839     2840      2841         2842     2843     2844  \
# Predicted  8533.7  15878.27  4580.74  10042.03  3983.444464  12898.0  12898.0
# Original   6790.0  20747.00  4544.00  10031.00  3943.000000  12898.0  12898.0
#
#               2845      2846     2847      2848     2849      2850      2851  \
# Predicted  7185.04  12870.54  7653.84  10593.96  10221.9  12386.86  8764.285
# Original   6961.00  12239.00  7335.00  10844.00  11134.0  12121.00  9929.000
#
#               2852          2853       2854          2855        2856  \
# Predicted  4058.61  10202.058145  4432.7492  10042.396866  4230.61378
# Original   4049.00   7408.000000  4462.0000   9646.000000  4332.00000
#
#                2857          2858     2859    2860     2861      2862  \
# Predicted  13525.77  13056.033333  2373.49  5530.7  4463.53  12286.49
# Original   13376.00  11467.000000  3210.00  5162.0  7120.00  10991.00
#
#               2863      2864      2865      2866          2867          2868  \
# Predicted  5684.84  10659.15   8619.42  13042.76  13132.926667   9724.645842
# Original   7202.00  10262.00  10112.00  12242.00  13014.000000  10529.000000
#
#                2869         2870      2871      2872         2873      2874  \
# Predicted  10273.68  4854.482769  6343.856  12972.26  12323.50755  11380.45
# Original    7757.00  4804.000000  6171.000  13029.00  12199.00000  10966.00
#
#               2875     2876      2877    2878      2879     2880     2881  \
# Predicted  8825.87  4331.28  10254.64  7064.0   8577.16  9506.47  4329.39
# Original   8066.00  4174.00  10703.00  7064.0  10794.00  7870.00  4049.00
#
#                    2882     2883          2884      2885         2886  \
# Predicted  12004.876667  14453.2  11260.980041  11151.85  7007.864958
# Original   14011.000000  14781.0  11622.000000  11087.00  8075.000000
#
#               2887     2888    2889     2890     2891          2892  \
# Predicted  6225.42  3505.59  8937.0  1996.88  4011.97  10909.934127
# Original   7229.00  3100.00  7090.0  1965.00  4483.00  10975.000000
#
#                    2893      2894     2895       2896     2897        2898  \
# Predicted  12081.459363  11078.27  10262.0  8419.5275  6407.11  11120.1575
# Original   12723.000000  11087.00  10262.0  8085.0000  6015.00  15812.0000
#
#                    2899    2900     2901    2902      2903     2904  \
# Predicted  13063.482222  5016.0  4952.99  7038.1  10838.58  11087.0
# Original   12970.000000  4995.0  4812.00  7754.0   9663.00  11087.0
#
#                   2905          2906      2907         2908     2909  \
# Predicted  8868.336492  13099.552325  13132.96  4893.962845  5245.66
# Original   7888.000000  13014.000000  14486.00  4804.000000  5176.00
#
#                2910      2911     2912     2913     2914      2915  \
# Predicted  10114.48  10404.44  7992.93  3666.66  5022.73  5983.794
# Original   10031.00  10368.00  6674.00  3100.00  5276.00  5575.000
#
#                   2916      2917      2918          2919      2920     2921  \
# Predicted  7811.998667  11666.15  16090.35   7776.836667  14510.86  6568.56
# Original   8283.000000  15136.00  16079.00  10067.000000  13941.00  5458.00
#
#              2922     2923         2924     2925     2926     2927    2928  \
# Predicted  7229.0  3392.76  6938.848833  8862.44  5023.02  7945.17  7064.0
# Original   7229.0  3625.00  4545.000000  9663.00  7202.00  8016.00  7064.0
#
#                2929     2930     2931          2932    2933      2934  \
# Predicted  14874.63  8919.17  4848.24  13714.468056  3903.4  12651.12
# Original   15353.00  9663.00  4878.00  14300.000000  3919.0  12681.00
#
#                2935         2936     2937      2938     2939    2940  \
# Predicted  10290.27  3601.377118  9151.34  14663.12  6335.24  7569.4
# Original   10262.00  3597.000000  8586.00  15164.00  6412.00  6628.0
#
#                  2941      2942         2943    2944     2945     2946  \
# Predicted  12650.7625  10863.77  6426.007768  6928.6  9273.92  7252.61
# Original   13428.0000  15812.00  5883.000000  6528.0  9345.00  7229.00
#
#               2947         2948     2949     2950     2951     2952     2953  \
# Predicted  2977.29  5078.371667  8428.25  10859.4  2395.96  4929.98  6543.99
# Original   2754.00  5615.000000  7757.00  10844.0  2227.00  4823.00  8001.00
#
#               2954         2955        2956     2957         2958      2959  \
# Predicted  9006.64  4950.914503  13683.9225  7767.57  8917.529643  12880.56
# Original   8855.00  5224.000000  13873.0000  6451.00  8366.000000  14973.00
#
#               2960      2961     2962        2963    2964     2965       2966  \
# Predicted  7794.14  14089.09  4939.37  4341.47761  7564.5   9770.7   9975.025
# Original   7894.00  13843.00  3383.00  4174.00000  7648.0  10539.0  13377.000
#
#                    2967      2968      2969     2970    2971      2972  \
# Predicted  10321.141464   9387.64  14750.18  4857.75  9564.0  11110.69
# Original   11447.000000  10112.00  14714.00  4649.00  9564.0  17524.00
#
#               2973     2974         2975      2976     2977         2978  \
# Predicted  3850.14  12255.1  9374.663093  12636.53   7910.6  4259.927598
# Original   3597.00  11342.0  6795.000000  10624.00  16162.0  4591.000000
#
#                2979     2980       2981     2982      2983     2984      2985  \
# Predicted  11856.21  6386.74  18448.295  8284.17  14058.79  3896.78  14718.56
# Original   12080.00  5073.00  20845.000  5192.00  13059.00  3873.00  14781.00
#
#                2986         2987         2988      2989     2990         2991  \
# Predicted  14706.73  7497.075365  3911.192545  11371.49  3416.65  6579.817917
# Original   14714.00  7048.000000  3858.000000  12384.00  2228.00  6442.000000
#
#               2992          2993         2994      2995     2996     2997  \
# Predicted  8384.48   9154.396914  8282.384524  12246.73  5373.62  7008.73
# Original   7980.00  13587.000000  8073.000000   9941.00  5947.00  6534.00
#
#                2998      2999      3000     3001      3002     3003      3004  \
# Predicted  11608.76  11241.38  12599.27  3590.66  13021.65  7570.75  14683.88
# Original   10031.00   7038.00  13067.00  3543.00  12898.00  6442.00  14219.00
#
#                3005      3006     3007         3008     3009         3010  \
# Predicted  12083.77  10521.35  4721.34  8728.110762  10262.0  4793.092538
# Original   11467.00  10262.00  4544.00  8285.000000  10262.0  4804.000000
#
#               3011         3012     3013      3014      3015     3016  \
# Predicted  2035.54  3649.075681  4712.77  18409.58  13156.55  5042.85
# Original   2017.00  3858.000000  4622.00  19828.00  12723.00  3383.00
#
#                3017      3018    3019      3020      3021      3022     3023  \
# Predicted  13318.13  10776.19  2676.0  12756.33  9206.853  4787.971  1987.56
# Original   12295.00  10844.00  2227.0  13879.00  8372.000  3873.000  2385.00
#
#               3024          3025     3026         3027         3028      3029  \
# Predicted  10262.0  13120.288333  6340.24  8172.713057  4833.836667  13972.54
# Original   10262.0  11467.000000  7514.00  7005.000000  4804.000000  15318.00
#
#                   3030     3031      3032         3033         3034     3035  \
# Predicted  8594.468206  9312.98  14977.32  6718.013609  4159.501667  4023.38
# Original   7155.000000  9345.00  14714.00  6442.000000  4423.000000  4030.00
#
#                3036     3037         3038     3039     3040     3041  \
# Predicted  12978.33  7821.93  13469.14006  7882.38  3594.29  3781.84
# Original   13626.00  6442.00  15129.00000  8366.00  3514.00  3573.00
#
#                   3042         3043     3044     3045      3046         3047  \
# Predicted  4801.495366  6443.646667  10262.0  4384.35  17385.02  4315.639167
# Original   4804.000000  6171.000000  10262.0  3971.00  17471.00  3873.000000
#
#                3048     3049     3050     3051         3052       3053  \
# Predicted  10816.22  5768.05  9330.94  6063.51  3667.587772  4863.0935
# Original   10844.00  5769.00  9663.00  5797.00  3898.000000  4441.0000
#
#                3054          3055     3056    3057     3058     3059    3060  \
# Predicted  13708.41  10358.339941  14657.1  7756.5  5267.13  5257.16  9371.3
# Original   13067.00   9315.000000  14571.0  5307.0  5969.00  5221.00  8586.0
#
#                  3061     3062     3063      3064     3065      3066  \
# Predicted  7836.72119  8452.43  8084.88  13550.26  5322.63  11349.74
# Original   7303.00000  7480.00  8040.00  13339.00  4957.00  12898.00
#
#                    3067      3068    3069       3070      3071     3072  \
# Predicted   8641.778333  14846.37  4356.8  10643.185  10502.32  6485.72
# Original   16754.000000  14714.00  5198.0  11038.000  10844.00  7438.00
#
#                3073         3074      3075         3076     3077     3078  \
# Predicted  15780.12  4655.856579   8181.01  6518.832917  6043.14  6496.91
# Original   20747.00  4804.000000  10844.00  7378.000000  5912.00  6297.00
#
#                3079     3080      3081     3082         3083     3084  \
# Predicted  16680.47  13046.4  15942.69  10844.0  8167.607429  4070.79
# Original   18192.00  13044.0  16263.00   8586.0  8285.000000  3311.00
#
#               3085      3086      3087       3088    3089     3090  \
# Predicted  5173.96   9658.06  5504.045  13572.145  5106.3  2059.42
# Original   4030.00  10493.00  4729.000  19372.000  5201.0  1965.00
#
#                    3091          3092     3093         3094      3095  \
# Predicted  11892.624888  11196.602042  7950.94  9269.430167  10708.29
# Original   12402.000000   7354.000000  7832.00  7240.000000  13542.00
#
#                 3096    3097     3098     3099         3100          3101  \
# Predicted  9908.5975  7853.8  16110.5  5160.99  4471.328502  12471.363889
# Original   9626.0000  7480.0  16079.0  5277.00  4148.000000  12723.000000
#
#                3102      3103      3104      3105      3106         3107  \
# Predicted   9812.22  14937.57  14376.55  14710.87  10295.12  9221.812667
# Original   10539.00  14960.00  13555.00  14781.00  10262.00  7530.000000
#
#               3108         3109     3110     3111    3112          3113  \
# Predicted  10488.8  4532.487662  6194.96  5228.76  6179.2  10808.998304
# Original   10262.0  4462.000000  7060.00  4409.00  5699.0  10678.000000
#
#                    3114      3115      3116     3117     3118      3119  \
# Predicted  11597.294983  12568.49  13975.84  14316.9  3370.81  10702.35
# Original   10877.000000  13067.00  13731.00  14571.0  2754.00  10929.00
#
#               3120      3121     3122         3123    3124          3125  \
# Predicted  6147.87  10982.08  6576.36  15033.95125  5715.0  10193.151429
# Original   6528.00  12898.00  7074.00  15135.00000  5912.0   9653.000000
#
#                   3126          3127         3128          3129        3130  \
# Predicted  6051.718333  12272.101143  6804.813333  10838.226527  5332.75557
# Original   7229.000000  12646.000000  6206.000000   9653.000000  7295.00000
#
#                3131      3132     3133      3134     3135          3136  \
# Predicted  10809.93  10336.53  10262.0  15114.84  5166.86  11200.611631
# Original   10844.00   8627.00  10262.0  15129.00  4823.00  11806.000000
#
#                   3137       3138      3139         3140         3141     3142
# Predicted  5200.280667  15550.885  4403.564  7825.023238  9324.870159  4843.35
# Original   3383.000000  16289.000  4409.000  6860.000000  7408.000000  4668.00

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, Predicted, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(Predicted), max(y_test))
p2 = min(min(Predicted), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual Price', fontsize=15)
plt.ylabel('Predicted Price', fontsize=15)
plt.axis('equal')
plt.show()

# %% [markdown]
# # Test Data

# %%
Flight_Test=pd.read_excel("Test_set.xlsx") #reading Flight_Train.xlsx file
Flight_Test.head() #Looking into top 5 rows
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
#Replacing null values with mode becuase the type of objects are object
Flight_Test['Route'].fillna(Flight_Test['Route'].mode()[0], inplace=True)
Flight_Test['Total_Stops'].fillna(Flight_Test['Total_Stops'].mode()[0], inplace=True)

# %%
#Replacing No Info to No info.
Flight_Test["Additional_Info"]=Flight_Test["Additional_Info"].replace("No Info","No info")

# %%
#Replacing String to numeric for better prediction
Flight_Test.replace({"non-stop": 0, 
                      "1 stop": 1, 
                      "2 stops": 2, 
                      "3 stops": 3, 
                      "4 stops": 4
                     }, inplace = True)

# %%
#Converting Duration from string to numbers
Flight_Test['hour'] = Flight_Test['Duration'].str.split("h").str[0]
Flight_Test['nothing'] = Flight_Test['Duration'].str.split(" ").str[1]
Flight_Test['minute'] = Flight_Test['nothing'].str.split("m").str[0]
Flight_Test.drop('nothing',axis=1,inplace=True)

# %%
Flight_Test.shape
# Out:
# (2671, 12)

# %%
for i in range(0,2670):
    if(Flight_Test['hour'][i] == '5m'):
        Flight_Test["hour"][i] = 0
        Flight_Test["minute"][i] = 5

# %%
Flight_Test['hour'] = pd.to_numeric(Flight_Test['hour']) #Converting object to numeric
Flight_Test['minute'] = pd.to_numeric(Flight_Test['minute']) #Converting object to numeric
Flight_Test['minute']=Flight_Test['minute'].replace(np.NaN,0) #Replacing null values with 0
Flight_Test['minute'] = Flight_Test['minute'].astype('int64') #Converting float to int
Flight_Test['Duration'] = Flight_Test['hour']*60 + Flight_Test['minute'] #Converting hours and minutes into minutes
Flight_Test.drop('hour',axis=1,inplace=True) #Dropping hour becuase work is over
Flight_Test.drop('minute',axis=1,inplace=True) #Dropping minute becuase work is over
Flight_Test.head() #Checking first 5 rows of data
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time  Duration  Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun       655            1                      No info
# 1    06:20         10:20       240            1                      No info
# 2    19:15  19:00 22 May      1425            1  In-flight meal not included
# 3    08:00         21:00       780            1                      No info
# 4    23:55  02:45 25 Jun       170            0                      No info

# %%
#Converting Departure time into minutes
Flight_Test['Dep_Time'] = pd.to_datetime(Flight_Test['Dep_Time'],format = '%H:%M').dt.hour*60 + pd.to_datetime(Flight_Test['Dep_Time'],format = '%H:%M').dt.minute

# %%
#Converting date into numeric form
import datetime as dt
Flight_Test['Date_of_Journey'] = pd.to_datetime(Flight_Test['Date_of_Journey'])
Flight_Test['Date_of_Journey'] = Flight_Test['Date_of_Journey'].map(dt.datetime.toordinal)
Flight_Test.head() #Checking top 5 rows of dataset
# Out:
#              Airline  Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways           737216     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo           737398   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways           737200     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers           737200     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia           737234  Banglore       Delhi        BLR → DEL
#
#    Dep_Time  Arrival_Time  Duration  Total_Stops              Additional_Info
# 0      1050  04:25 07 Jun       655            1                      No info
# 1       380         10:20       240            1                      No info
# 2      1155  19:00 22 May      1425            1  In-flight meal not included
# 3       480         21:00       780            1                      No info
# 4      1435  02:45 25 Jun       170            0                      No info

# %%
#We have Total_Stops columns, So we don't need Route column
#We have Dep_Time and Duration that is equailent to Arrival time, So we don't need it.
Flight_Test.drop('Route',axis=1,inplace=True)
Flight_Test.drop('Arrival_Time',axis=1,inplace=True)

# %%
Flight_Test.head()
# Out:
#              Airline  Date_of_Journey    Source Destination  Dep_Time  \
# 0        Jet Airways           737216     Delhi      Cochin      1050
# 1             IndiGo           737398   Kolkata    Banglore       380
# 2        Jet Airways           737200     Delhi      Cochin      1155
# 3  Multiple carriers           737200     Delhi      Cochin       480
# 4           Air Asia           737234  Banglore       Delhi      1435
#
#    Duration  Total_Stops              Additional_Info
# 0       655            1                      No info
# 1       240            1                      No info
# 2      1425            1  In-flight meal not included
# 3       780            1                      No info
# 4       170            0                      No info

# %%
#Label encoding for the object columns
label_list=list(Flight_Test.select_dtypes(['object']).columns)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() #Initlize LabelEncoder to le 
for i in label_list:
    Flight_Test[i] = le.fit_transform(Flight_Test[i])

# %%
z=np.abs(zscore(Flight_Test))
print(np.where(z>3))
# Out:
# (array([  72,  251,  251,  484,  510,  673,  725,  786,  875,  877,  954,
#        1022, 1271, 1279, 1379, 1511, 1554, 1686, 1689, 1689, 1781, 1802,
#        1861, 1918, 1945, 2021, 2114, 2359, 2422, 2442, 2472, 2487, 2492],
#       dtype=int64), array([6, 5, 6, 6, 5, 6, 6, 5, 6, 6, 7, 5, 5, 5, 5, 5, 5, 5, 5, 6, 5, 7,
#        7, 5, 5, 6, 5, 5, 6, 6, 5, 6, 5], dtype=int64))

# %%
z=np.abs(zscore(Flight_Test))
threshold=3
new_Flight_Test=Flight_Test[(z<3).all(axis=1)]
print(Flight_Test.shape)
print(new_Flight_Test.shape)
# Out:
# (2671, 8)
# (2640, 8)

# %%
#checking for how much data we lost
loss_percent=(2671-2640)/2671*100
print(loss_percent)
# Out:
# 1.1606140022463498

# %%
#Removing skewness from non object columns
from sklearn.preprocessing import PowerTransformer
PT=PowerTransformer()
for i in new_Flight_Test.columns:
    if abs(new_Flight_Test.loc[:,i].skew())>0.55:
        new_Flight_Test.loc[:,i]=PT.fit_transform(new_Flight_Test.loc[:,i].values.reshape(-1,1))

# %%
x=new_Flight_Test

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler() #Initializting MinMaxScaler
new = scale.fit(x)  #fitting our data into MinMaxScaller
scale_x = new.transform(x) #Transforming the data
#Setting up the coulumns after Scaling
scaled_x = pd.DataFrame(scale_x, index=x.index, columns=x.columns)
x=scaled_x
x.head() #Priting top 5 rows of our data
# Out:
#    Airline  Date_of_Journey  Source  Destination  Dep_Time  Duration  \
# 0      0.4         0.456973    0.50     0.439690  0.726950  0.723130
# 1      0.3         0.997033    0.75     0.000000  0.251773  0.523724
# 2      0.4         0.409496    0.50     0.439690  0.801418  0.899682
# 3      0.6         0.409496    0.50     0.439690  0.322695  0.761021
# 4      0.0         0.510386    0.00     0.664262  1.000000  0.461984
#
#    Total_Stops  Additional_Info
# 0          0.5              1.0
# 1          0.5              1.0
# 2          0.5              0.0
# 3          0.5              1.0
# 4          0.0              1.0

# %%
Predicted = RF_from_joblib.predict(x)
Predicted
# Out:
# array([ 6435.5       ,  4597.03      ,  9147.35      , ...,
#        13492.39      , 11585.04      , 10145.48594694])
